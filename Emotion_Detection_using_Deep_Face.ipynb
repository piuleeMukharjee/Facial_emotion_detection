# %% [markdown]
# <a href="https://colab.research.google.com/github/piuleeMukharjee/Facial_emotion_detection/blob/main/Emotion_Detection_using_Deep_Face.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Design an AI-enabled application for emotion/gesture detection.**

# %% [markdown]
# Deepface is a lightweight face recognition and facial attribute analysis (age, gender, emotion and race) framework for python. It is a hybrid face recognition framework wrapping state-of-the-art models: VGG-Face, Google FaceNet, OpenFace, Facebook DeepFace, DeepID, ArcFace and Dlib. Those models already reached and passed the human level accuracy. The library is mainly based on Keras and TensorFlow.

# %%
# !pip install deepface &> /dev/null #to install the DeepFace package which will install the library itself and all prerequisites
print ("Deep Face installed sucessfully!!")
# Out:
# Deep Face installed sucessfully!!

# %%
from deepface import DeepFace #to import the library and use its functionalities
##Load and display input image
import cv2 #to import cv2
#OpenCV is a great tool for image processing and performing computer vision tasks. It is an open-source library that can be used to perform tasks like face detection, objection tracking, landmark detection, and much more.
import matplotlib.pyplot as plt #to import matplotlib for graphical features
img1=cv2.imread("/content/Screenshot 2024-08-14 225055.png") #to read the image
plt.imshow(img1) #to show image in bgr format
plt.show()

# %% [markdown]
# # New section

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Plotting the image
# Flipping the color from BGR to RGB
plt.imshow(img1[:, :, ::-1 ])
plt.show()

# %%
##Analyze different features of the Image
obj=DeepFace.analyze(img1, actions = ['age', 'gender', 'race', 'emotion'])
print(obj)
# Out:
# Action: age:   0%|          | 0/4 [00:00<?, ?it/s]
# 24-08-14 17:26:07 - age_model_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/age_model_weights.h5
# To: /root/.deepface/weights/age_model_weights.h5
#
#   0%|          | 0.00/539M [00:00<?, ?B/s]
#   2%|▏         | 11.0M/539M [00:00<00:06, 82.0MB/s]
#   6%|▌         | 31.5M/539M [00:00<00:03, 145MB/s]
#   9%|▉         | 47.2M/539M [00:00<00:03, 130MB/s]
#  12%|█▏        | 63.4M/539M [00:00<00:03, 122MB/s]
#  15%|█▌        | 82.3M/539M [00:00<00:03, 142MB/s]
#  18%|█▊        | 97.5M/539M [00:00<00:03, 130MB/s]
#  22%|██▏       | 116M/539M [00:00<00:03, 128MB/s]
#  25%|██▍       | 133M/539M [00:01<00:02, 140MB/s]
#  27%|██▋       | 148M/539M [00:01<00:03, 127MB/s]
#  31%|███       | 168M/539M [00:01<00:02, 145MB/s]
#  34%|███▍      | 184M/539M [00:01<00:02, 129MB/s]
#  37%|███▋      | 200M/539M [00:01<00:02, 128MB/s]
# ...

# %%
##Print Result
print("Your age is",obj[0]['age'],"and you are",obj[0]["dominant_race"],"and current emotion is ",obj[0]["dominant_emotion"],"and your gender capture is", obj[0]['dominant_gender'])
# Out:
# Your age is 34 and you are white and current emotion is  fear and your gender capture is Woman

# %%
from deepface import DeepFace #to import the library and use its functionalities
##Load and display input image
import cv2 #to import cv2
#OpenCV is a great tool for image processing and performing computer vision tasks. It is an open-source library that can be used to perform tasks like face detection, objection tracking, landmark detection, and much more.
import matplotlib.pyplot as plt #to import matplotlib for graphical features
img1=cv2.imread("/content/Screenshot 2024-08-14 225145.png") #to read the image
plt.imshow(img1) #to show image in bgr format
plt.show()

# %%
plt.imshow(img1[:, :, ::-1 ])
plt.show()

# %%
obj=DeepFace.analyze(img1, actions = ['age', 'gender', 'race', 'emotion'])
print(obj)
# Out:
# Action: emotion: 100%|██████████| 4/4 [00:01<00:00,  2.14it/s]
# [{'age': 31, 'region': {'x': 391, 'y': 58, 'w': 147, 'h': 147, 'left_eye': None, 'right_eye': None}, 'face_confidence': 0.91, 'gender': {'Woman': 99.99932050704956, 'Man': 0.0006826436219853349}, 'dominant_gender': 'Woman', 'race': {'asian': 0.010060305538558502, 'indian': 0.0014207253900324925, 'black': 1.9248994383819257e-05, 'white': 98.65929468384918, 'middle eastern': 0.6122314635344104, 'latino hispanic': 0.7169789092366587}, 'dominant_race': 'white', 'emotion': {'angry': 1.8293571952404664e-10, 'disgust': 2.87521538769736e-19, 'fear': 1.4354524513482403e-09, 'happy': 99.35826659202576, 'sad': 1.8977939220121698e-07, 'surprise': 0.0002048582018687739, 'neutral': 0.6415280979126692}, 'dominant_emotion': 'happy'}]

# %%
print("Your age is",obj[0]['age'],"and you are",obj[0]["dominant_race"],"and current emotion is ",obj[0]["dominant_emotion"],"and your gender capture is", obj[0]['dominant_gender'])
# Out:
# Your age is 31 and you are white and current emotion is  happy and your gender capture is Woman

# %%
from deepface import DeepFace #to import the library and use its functionalities
##Load and display input image
import cv2 #to import cv2
#OpenCV is a great tool for image processing and performing computer vision tasks. It is an open-source library that can be used to perform tasks like face detection, objection tracking, landmark detection, and much more.
import matplotlib.pyplot as plt #to import matplotlib for graphical features
img1=cv2.imread("/content/Screenshot 2024-08-14 225226.png") #to read the image
plt.imshow(img1) #to show image in bgr format
plt.show()

# %%
plt.imshow(img1[:, :, ::-1 ])
plt.show()

# %%
obj=DeepFace.analyze(img1, actions = ['age', 'gender', 'race', 'emotion'])
print(obj)
# Out:
# Action: emotion: 100%|██████████| 4/4 [00:01<00:00,  2.21it/s]
# [{'age': 24, 'region': {'x': 251, 'y': 107, 'w': 304, 'h': 304, 'left_eye': (453, 214), 'right_eye': (333, 235)}, 'face_confidence': 0.91, 'gender': {'Woman': 99.84727501869202, 'Man': 0.15272734453901649}, 'dominant_gender': 'Woman', 'race': {'asian': 22.093741595745087, 'indian': 2.2925743833184242, 'black': 0.7960665971040726, 'white': 40.00345170497894, 'middle eastern': 8.794871717691422, 'latino hispanic': 26.019299030303955}, 'dominant_race': 'white', 'emotion': {'angry': 0.0185101241857783, 'disgust': 3.7961070730131514e-10, 'fear': 0.07869470508496999, 'happy': 8.65822510390819e-06, 'sad': 1.0348239611299084, 'surprise': 2.2993015237497734e-05, 'neutral': 98.86793507719814}, 'dominant_emotion': 'neutral'}]

# %%
print("Your age is",obj[0]['age'],"and you are",obj[0]["dominant_race"],"and current emotion is ",obj[0]["dominant_emotion"],"and your gender capture is", obj[0]['dominant_gender'])
# Out:
# Your age is 24 and you are white and current emotion is  neutral and your gender capture is Woman
